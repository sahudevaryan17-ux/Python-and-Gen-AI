# %%
#variables : stores values and can vary.
age = 23 # age behaves as container which stores 23
name = "Dev"
height = 5.8
is_handsome = True
print("Age is: ",age)
print("Name is: ",name)
print("Height is: ",height)
print("he is : ",is_handsome,"handsome")
# Out:
# Age is:  23
# Name is:  Dev
# Height is:  5.8
# he is :  True handsome

# %%
#variables : stores values and can vary.
age = 23 
name = "Dev"
height = 5.8
is_handsome = True
print(type(age))
print(type(name))
print(type(height))
print(type(is_handsome),"handsome")
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'> handsome

# %%
'''
hello
'''
print("Multi line comment")
# Out:
# Multi line comment

# %%
age = 45

# %%
Age = str(age)

# %%
print(type(Age))
# Out:
# <class 'str'>

# %%
n1ame = "Dev"
n2ame = int(n1ame)
print(n2ame)
#this gives an error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 n1ame = "Dev"
# ----> 2 n2ame = int(n1ame)
#       3 print(n2ame)
#
# ValueError: invalid literal for int() with base 10: 'Dev'

# %% [markdown]
# we can do typecasting but we cannot type cast a [ string ] value to an [ integer ] value.

# %%
#using input() function to take input from the user
name = input("Enter Name : ")
# Out:
# 'Dev Aryan'

# %%
AGE = int(input("age batao bacchhi : "))#stores age
print (type(AGE))
# Out:
# <class 'int'>

# %%
#simple calculator

value_1 = int(input("Enter your first value: "))
value_2 = int(input("Enter your second value: "))
print("add: ",value_1 + value_2)
print("sub: ",value_1 - value_2)
print("div: ",value_1 / value_2)
print("mult: ",value_1 * value_2)
print("modulo: ",value_1 % value_2)
# Out:
# add:  15
# sub:  5
# div:  2.0
# mult:  50
# modulo:  0
