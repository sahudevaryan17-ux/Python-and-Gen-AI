# %%
import sys
import numpy
import pandas
import openai

print(sys.executable)
print("Everything is working ✅")
# Out:
# c:\Python\Python-and-Gen-AI\.venv\Scripts\python.exe
# Everything is working ✅

# %%
print("hello world!!!")
# Out:
# hello world!!!

# %%
name  = "Dev"
Name = "Dev"
name == Name
# Out:
# True

# %%
name = "Dev"
Name = "dev"
name == Name #comparision operator
# Out:
# False

# %%
#indentation
age = int(input("Enter Your age: "))
if age > 18 : 
    print("can vote!!")
# Out:
# can vote!!

# %%
age = int(input("Enter Your age: "))
if age > 18 :  
print("can vote!!")#this block gives an indentation error 
#to fix it press[ tab ]where the error is marked
# Out:
#   Cell In[6], line 3
#     print("can vote!!")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %% [markdown]
# use [ \ ] mark to continue in next line

# %% [markdown]
# dont use semicolon[ ; ] to end
